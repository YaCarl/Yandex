# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url = 'https://ru.wikipedia.org/wiki/%D0%9C%D0%B5%D0%B6%D0%B4%D1%83%D0%BD%D0%B0%D1%80%D0%BE%D0%B4%D0%BD%D1%8B%D0%B9_%D0%B8%D0%BD%D0%B4%D0%B5%D0%BA%D1%81_%D1%81%D1%87%D0%B0%D1%81%D1%82%D1%8C%D1%8F'
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text, 'lxml')

# %%
#print(soup.prettify())

# %%
mytable=soup.find_all('table',{'class':'wikitable sortable'})[2] #Выбираем только последнюю таблицу (2012)

# %%
A=[]
B=[]
C=[]
D=[]
E=[]
F=[]
for row in mytable.findAll('tr'):
    cells = row.findAll('td')
    if len(cells)==6: #только информация без заголовков
        A.append(cells[0].find(text=True))
        B.append(cells[1].find(text=True))
        C.append(cells[2].find(text=True))
        D.append(cells[3].find(text=True))
        E.append(cells[4].find(text=True))
        F.append(cells[5].find(text=True))

# %%
import pandas as pd
df=pd.DataFrame(A,columns=['Место'])
df['Место']=pd.to_numeric(A)
df['Страна']=B
df['HPI']=pd.to_numeric(C)
df['Удовлетворённость жизнью']=pd.to_numeric(D)
df['Ожидаемая продолжительность жизни']=pd.to_numeric(E)
df['Экологический след']=pd.to_numeric(F)

# %%
df
# Out:
#     Место                    Страна   HPI  Удовлетворённость жизнью  \
# 0       1                Коста-Рика  64.0                       7.3
# 1       2                   Вьетнам  60.4                       5.8
# 2       3                  Колумбия  59.8                       6.4
# 3       4                     Белиз  59.3                       6.5
# 4       5                 Сальвадор  58.9                       6.7
# 5       6                    Ямайка  58.5                       6.2
# 6       7                    Панама  57.8                       7.3
# 7       8                 Никарагуа  57.1                       5.7
# 8       9                 Венесуэла  56.9                       7.5
# 9      10                 Гватемала  56.9                       6.3
# 10     11                 Бангладеш  56.3                       5.0
# 11     12                      Куба  56.2                       5.4
# 12     13                  Гондурас  56.0                       5.9
# ...

# %%
#from pandas.api.types import is_string_dtype
#from pandas.api.types import is_numeric_dtype
#is_string_dtype(df['Страна'])
# Out:
# True

# %%
df.to_csv('html-Zybin')
