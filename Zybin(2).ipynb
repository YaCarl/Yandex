# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/irina/Desktop/Fishing.csv")

# %%
df = pd.read_csv("Fishing.csv")

# %%
df.describe()
# Out:
#         Unnamed: 0        price        catch       pbeach        ppier  \
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean    591.500000    52.081975     0.389368   103.422005   103.422005
# std     341.358316    53.829970     0.560596   103.641042   103.641042
# min       1.000000     1.290000     0.000200     1.290000     1.290000
# 25%     296.250000    15.870000     0.036100    26.656500    26.656500
# 50%     591.500000    37.896000     0.164300    74.628000    74.628000
# 75%     886.750000    67.513000     0.533300   144.144000   144.144000
# max    1182.000000   666.110000     2.310100   843.186000   843.186000
#
#              pboat     pcharter       cbeach        cpier        cboat  \
# count  1182.000000  1182.000000  1182.000000  1182.000000  1182.000000
# mean     55.256570    84.379244     0.241011     0.162224     0.171215
# std      62.713444    63.544650     0.190752     0.160390     0.209789
# ...

# %%
df[df["mode"]=="beach"]
# Out:
#       Unnamed: 0   mode    price   catch   pbeach    ppier    pboat  pcharter  \
# 6              7  beach   51.934  0.0678   51.934   51.934  191.930   220.930
# 14            15  beach   74.514  0.2537   74.514   74.514   74.514    93.014
# 16            17  beach   48.114  0.1049   48.114   48.114   33.534    57.534
# 25            26  beach   67.784  0.5333   67.784   67.784   17.862    52.862
# 33            34  beach    9.522  0.0678    9.522    9.522   78.292   107.292
# 48            49  beach   24.334  0.0678   24.334   24.334   89.930   118.930
# 49            50  beach   11.322  0.0678   11.322   11.322   93.092   122.092
# 75            76  beach    9.522  0.0678    9.522    9.522   78.292   107.292
# 76            77  beach   24.696  0.0678   24.696   24.696  111.132   140.132
# 81            82  beach    7.722  0.0678    7.722    7.722   63.492    92.492
# 99           100  beach   31.740  0.2537   31.740   31.740   38.088    56.588
# ...

# %%
df[(df["mode"]=="beach")&(df["income"]<3500)]
# Out:
#       Unnamed: 0   mode    price   catch   pbeach    ppier    pboat  pcharter  \
# 25            26  beach   67.784  0.5333   67.784   67.784   17.862    52.862
# 81            82  beach    7.722  0.0678    7.722    7.722   63.492    92.492
# 100          101  beach   19.740  0.2537   19.740   19.740   23.688    42.188
# 165          166  beach   15.572  0.0678   15.572   15.572   38.014    67.014
# 173          174  beach   22.372  0.0678   22.372   22.372   54.614    83.614
# 261          262  beach    4.122  0.0678    4.122    4.122    4.122    29.122
# 305          306  beach   11.186  0.0678   11.186   11.186   11.186    36.186
# 324          325  beach    4.290  0.0678    4.290    4.290    4.290    29.290
# 336          337  beach    2.290  0.0678    2.290    2.290    2.290    27.290
# 361          362  beach    4.122  0.0678    4.122    4.122    4.122    29.122
# 370          371  beach   37.098  0.0678   37.098   37.098   37.098    66.098
# ...

# %%
my_cols=list(df.columns)
my_cols[3]="c_rate"
df.columns=my_cols

# %%
import numpy
df["log_income"]=numpy.log(df["income"])

# %%
df.groupby('mode')

# %%
regs=df.groupby('mode').agg('mean')
regs['price']
# Out:
# mode
# beach      35.699493
# boat       41.606813
# charter    75.096942
# pier       30.571326
# Name: price, dtype: float64

# %%
df["pboat"].plot.hist(color = "purple", title="Turtle")

# %%
df.head(8)
# Out:
#    Unnamed: 0     mode    price  c_rate   pbeach    ppier    pboat  pcharter  \
# 0           1  charter  182.930  0.5391  157.930  157.930  157.930   182.930
# 1           2  charter   34.534  0.4671   15.114   15.114   10.534    34.534
# 2           3     boat   24.334  0.2413  161.874  161.874   24.334    59.334
# 3           4     pier   15.134  0.0789   15.134   15.134   55.930    84.930
# 4           5     boat   41.514  0.1082  106.930  106.930   41.514    71.014
# 5           6  charter   63.934  0.3975  192.474  192.474   28.934    63.934
# 6           7    beach   51.934  0.0678   51.934   51.934  191.930   220.930
# 7           8  charter   56.714  0.0209   15.134   15.134   21.714    56.714
#
#    cbeach   cpier   cboat  ccharter     income  log_income
# 0  0.0678  0.0503  0.2601    0.5391  7083.3317    8.865500
# 1  0.1049  0.0451  0.1574    0.4671  1249.9998    7.130899
# 2  0.5333  0.4522  0.2413    1.0266  3749.9999    8.229511
# ...

# %%
df.tail(8)
# Out:
#       Unnamed: 0     mode    price  c_rate   pbeach    ppier    pboat  \
# 1174        1175     boat   86.802  0.0102   91.834   91.834   86.802
# 1175        1176  charter  149.402  0.0209  121.034  121.034  114.402
# 1176        1177    beach  121.836  0.5333  121.836  121.836  203.346
# 1177        1178     pier  150.236  0.4522  150.236  150.236  250.746
# 1178        1179    beach  235.436  0.5333  235.436  235.436  392.946
# 1179        1180     pier   65.036  0.4522   65.036   65.036  108.546
# 1180        1181    beach   36.636  0.5333   36.636   36.636   61.146
# 1181        1182     boat  235.436  0.6817  339.890  339.890  235.436
#
#       pcharter  cbeach   cpier   cboat  ccharter      income  log_income
# 1174   121.802  0.0678  0.0789  0.0102    0.0209  4583.33200    8.430182
# 1175   149.402  0.0678  0.0789  0.0102    0.0209  6250.00130    8.740337
# 1176   238.346  0.5333  0.4522  0.2413    1.0266  2916.66660    7.978197
# ...

# %%
df.to_csv('Fishing-new.csv')

# %%
df=pd.read_excel('polit.xlsx')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 12 columns):
# ctry        213 non-null object
# fh09        191 non-null float64
# polity09    159 non-null float64
# gini        146 non-null float64
# fparl08     186 non-null float64
# mena        213 non-null int64
# lati        213 non-null int64
# cari        213 non-null int64
# east        213 non-null int64
# sovi        213 non-null int64
# afri        213 non-null int64
# corr0509    203 non-null float64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 20.0+ KB

# %%
df=df.dropna()

# %%
df.describe()
# Out:
#              fh09    polity09        gini     fparl08        mena        lati  \
# count  135.000000  135.000000  135.000000  135.000000  135.000000  135.000000
# mean     3.325926    4.651852   40.569630   18.348074    0.081481    0.140741
# std      1.796886    5.636129    9.432987   10.410612    0.274592    0.349049
# min      1.000000  -10.000000   16.800000    0.000000    0.000000    0.000000
# 25%      1.500000    0.000000   34.000000   10.340000    0.000000    0.000000
# 50%      3.500000    7.000000   39.200000   16.110000    0.000000    0.000000
# 75%      5.000000    9.000000   47.100000   25.335000    0.000000    0.000000
# max      7.000000   10.000000   74.300000   50.940000    1.000000    1.000000
#
#              cari        east        sovi        afri    corr0509
# count  135.000000  135.000000  135.000000  135.000000  135.000000
# mean     0.022222    0.081481    0.081481    0.281481   -0.104802
# std      0.147955    0.274592    0.274592    0.451397    0.993943
# ...

# %% [markdown]
# ## Столбец "fh09"
# count: в столбце содержится 135 значений;
# mean: среднее значение - 3.326;
# std: каждое значение в среднем отклоняется на 1.797 от среднего значения;
# 25%: первому квартилю соответствует значение 1.5;
# 50%: медиане соответствует значение 3.5;
# 75%: третьему квартилю соответствует значение 5;
# max: максимальное значение 7;

# %%
not_free=df[df["fh09"]>5]

# %%
df[(df["afri"]==1)&(df["fparl08"]>30)]
# Out:
#              ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  \
# 30        Burundi   4.5       6.0  33.3    31.74     0     0     0     0
# 133    Mozambique   3.5       5.0  47.1    34.80     0     0     0     0
# 160        Rwanda   5.5      -3.0  46.7    50.94     0     0     0     0
# 174  South Africa   2.0       9.0  57.8    33.92     0     0     0     0
# 187      Tanzania   3.5      -1.0  34.6    30.41     0     0     0     0
# 198        Uganda   4.5      -1.0  42.6    30.72     0     0     0     0
#
#      sovi  afri  corr0509
# 30      0     1 -1.095802
# 133     0     1 -0.524405
# 160     0     1 -0.164223
# 174     0     1  0.332960
# 187     0     1 -0.439213
# 198     0     1 -0.819751

# %%
df[(df["afri"]==1)&(df["polity09"]>=8)|(df["lati"]==1)&(df["polity09"]>=8)]
# Out:
#                    ctry  fh09  polity09  gini  fparl08  mena  lati  cari  \
# 7             Argentina   2.0       8.0  48.8    39.76     0     1     0
# 25             Botswana   2.5       8.0  61.0    11.11     0     0     0
# 26               Brazil   2.0       8.0  55.0     9.43     0     1     0
# 39                Chile   1.0      10.0  52.0    12.66     0     1     0
# 42              Comoros   3.5       9.0  64.3     3.03     0     0     0
# 45           Costa Rica   1.0      10.0  48.9    36.84     0     1     0
# 54   Dominican Republic   2.0       8.0  48.4    17.14     0     1     0
# 57          El Salvador   2.5       8.0  46.9    16.67     0     1     0
# 71                Ghana   1.5       8.0  42.8     7.89     0     0     0
# 77            Guatemala   4.0       8.0  53.7    12.03     0     1     0
# 108             Lesotho   3.0       8.0  52.5    25.83     0     0     0
# 126              Mexico   2.5       8.0  51.6    22.13     0     1     0
# ...

# %%
df.sort_values('corr0509',ascending = False)
# Out:
#                          ctry  fh09  polity09  gini  fparl08  mena  lati  \
# 51                    Denmark   1.0      10.0  24.7    37.99     0     0
# 64                    Finland   1.0      10.0  26.9    41.50     0     0
# 140               New Zealand   1.0      10.0  36.2    33.61     0     0
# 169                 Singapore   4.5      -2.0  42.5    24.47     0     0
# 183                    Sweden   1.0      10.0  25.0    46.99     0     0
# 137               Netherlands   1.0      10.0  30.9    39.11     0     0
# 184               Switzerland   1.0      10.0  33.7    27.24     0     0
# 10                  Australia   1.0      10.0  35.2    29.65     0     0
# 145                    Norway   1.0      10.0  25.8    36.09     0     0
# 33                     Canada   1.0      10.0  32.6    24.94     0     0
# 11                    Austria   1.0      10.0  29.1    26.64     0     0
# 70                    Germany   1.0      10.0  28.3    31.13     0     0
# ...

# %%
df.head(10)
# Out:
#           ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  sovi  \
# 1      Albania   3.0       9.0  33.0     7.14     0     0     0     0     1
# 2      Algeria   5.5       2.0  35.3     6.48     1     0     0     0     0
# 5       Angola   5.5      -2.0  58.6    37.27     0     0     0     0     0
# 7    Argentina   2.0       8.0  48.8    39.76     0     1     0     0     0
# 8      Armenia   5.0       5.0  30.2     8.40     0     0     0     0     0
# 10   Australia   1.0      10.0  35.2    29.65     0     0     0     0     0
# 11     Austria   1.0      10.0  29.1    26.64     0     0     0     0     0
# 12  Azerbaijan   5.5      -7.0  16.8    11.38     0     0     0     0     0
# 15  Bangladesh   3.5       5.0  31.0     6.33     0     0     0     0     0
# 17     Belarus   6.5      -7.0  28.8    32.53     0     0     0     0     0
#
#     afri  corr0509
# 1      0 -0.580513
# 2      0 -0.434654
# 5      0 -1.292684
# 7      0 -0.420793
# 8      0 -0.578211
# ...

# %%
df.tail(10)
# Out:
#                ctry  fh09  polity09  gini  fparl08  mena  lati  cari  east  \
# 199         Ukraine   2.5       7.0  27.6     8.22     0     0     0     0
# 201  United Kingdom   1.0      10.0  36.0    19.61     0     0     0     0
# 202   United States   1.0      10.0  40.8    17.01     0     0     0     0
# 203         Uruguay   1.0      10.0  47.1    12.31     0     1     0     0
# 204      Uzbekistan   7.0      -9.0  36.7    16.36     0     0     0     0
# 206   Venezuela, RB   4.5      -3.0  43.4    18.56     0     1     0     0
# 207         Vietnam   6.0      -7.0  37.8    25.76     0     0     0     1
# 210     Yemen, Rep.   5.5      -2.0  37.7     0.73     1     0     0     0
# 211          Zambia   3.5       7.0  50.7    15.19     0     0     0     0
# 212        Zimbabwe   6.0       1.0  50.1    18.15     0     0     0     0
#
#      sovi  afri  corr0509  corr_round
# 199     0     0 -0.722976       -0.72
# 201     0     0  1.714137        1.71
# ...
